# %% [markdown]
# # 🐍 Python Libraries Showcase (30 Libraries with Examples)
#
# This notebook introduces 30 popular Python libraries with:
# - Short explanation
# - Simple example code
# - Beginner-friendly structure
#
# ⚠ Some advanced libraries (like TensorFlow, PyTorch) may require installation before running.

# %% [markdown]
# ## 📦 NumPy
# Simple Example:

# %%
import numpy as np
arr = np.array([1,2,3])
print(arr * 2)

# %% [markdown]
# ## 📦 Pandas
# Simple Example:

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
print(df)

# %% [markdown]
# ## 📦 Matplotlib
# Simple Example:

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.show()

# %% [markdown]
# ## 📦 Seaborn
# Simple Example:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x=[1,2,3], y=[3,2,5])
plt.show()

# %% [markdown]
# ## 📦 Scikit-learn
# Simple Example:

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# ## 📦 TensorFlow
# Simple Example:

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ## 📦 Keras
# Simple Example:

# %%
from keras.models import Sequential
model = Sequential()

# %% [markdown]
# ## 📦 PyTorch
# Simple Example:

# %%
import torch
x = torch.tensor([1,2,3])
print(x)

# %% [markdown]
# ## 📦 XGBoost
# Simple Example:

# %%
import xgboost as xgb
print('XGBoost Loaded')

# %% [markdown]
# ## 📦 LightGBM
# Simple Example:

# %%
import lightgbm as lgb
print('LightGBM Loaded')

# %% [markdown]
# ## 📦 Django
# Simple Example:

# %%
# Django is a web framework
# django-admin startproject myproject

# %% [markdown]
# ## 📦 Flask
# Simple Example:

# %%
from flask import Flask
app = Flask(__name__)

# %% [markdown]
# ## 📦 FastAPI
# Simple Example:

# %%
from fastapi import FastAPI
app = FastAPI()

# %% [markdown]
# ## 📦 Requests
# Simple Example:

# %%
import requests
response = requests.get('https://example.com')
print(response.status_code)

# %% [markdown]
# ## 📦 BeautifulSoup
# Simple Example:

# %%
from bs4 import BeautifulSoup
html = '<h1>Hello</h1>'
soup = BeautifulSoup(html, 'html.parser')
print(soup.h1.text)

# %% [markdown]
# ## 📦 Plotly
# Simple Example:

# %%
import plotly.express as px
fig = px.line(x=[1,2,3], y=[3,1,4])
fig.show()

# %% [markdown]
# ## 📦 Bokeh
# Simple Example:

# %%
from bokeh.plotting import figure, show
p = figure()
p.line([1,2,3],[4,6,2])
show(p)

# %% [markdown]
# ## 📦 Altair
# Simple Example:

# %%
import altair as alt
import pandas as pd
df = pd.DataFrame({'x':[1,2,3],'y':[3,2,1]})
chart = alt.Chart(df).mark_line().encode(x='x', y='y')
chart

# %% [markdown]
# ## 📦 OpenCV
# Simple Example:

# %%
import cv2
print(cv2.__version__)

# %% [markdown]
# ## 📦 Pillow
# Simple Example:

# %%
from PIL import Image
print('Pillow Loaded')

# %% [markdown]
# ## 📦 PyAutoGUI
# Simple Example:

# %%
import pyautogui
print(pyautogui.size())

# %% [markdown]
# ## 📦 Selenium
# Simple Example:

# %%
from selenium import webdriver
print('Selenium Ready')

# %% [markdown]
# ## 📦 Schedule
# Simple Example:

# %%
import schedule
print('Scheduler Ready')

# %% [markdown]
# ## 📦 tqdm
# Simple Example:

# %%
from tqdm import tqdm
for i in tqdm(range(5)):
    pass

# %% [markdown]
# ## 📦 SciPy
# Simple Example:

# %%
import scipy
print(scipy.__version__)

# %% [markdown]
# ## 📦 SymPy
# Simple Example:

# %%
import sympy as sp
x = sp.symbols('x')
print(sp.integrate(x**2, x))

# %% [markdown]
# ## 📦 Statsmodels
# Simple Example:

# %%
import statsmodels.api as sm
print('Statsmodels Loaded')

# %% [markdown]
# ## 📦 Pygame
# Simple Example:

# %%
import pygame
print('Pygame Loaded')

# %% [markdown]
# ## 📦 Tkinter
# Simple Example:

# %%
import tkinter as tk
root = tk.Tk()
root.title('Sample Window')

# %% [markdown]
# ## 📦 SQLAlchemy
# Simple Example:

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')
