# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40-days-of-Python/blob/main/Beginner_to_advance_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Beginner to advance python for everyone

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
2+2
# Out:
# 4

# %%
2-2
# Out:
# 0

# %%
2*2
# Out:
# 4

# %%
2/2
# Out:
# 1.0

# %%
2//2
# Out:
# 1
