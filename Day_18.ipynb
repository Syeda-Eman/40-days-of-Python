# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40-days-of-Python/blob/main/Day_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Filtering Pandas DataFrame**

# %% [markdown]
# ### **Step 1: Loading Data**

# %%
import pandas as pd
brics=pd.read_csv("/content/brics.csv", index_col = 0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ### **Step 2: Get column**

# %%
brics["area"]
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
brics.loc[:,"area"]
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
brics.iloc[:,2]
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %% [markdown]
# ### **Step 3: Compare**

# %%
brics["area"]>8
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
is_huge=brics["area"]>8

# %%
is_huge
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %% [markdown]
# ### **Step 4: Subset DF**

# %%
brics[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %% [markdown]
# ### **Summarize**
# I selected the area column, performed a comparison on this column and the stored it as is_huge so that I can use it to index the brics DataFrame. These different commands do the trick.

# %%
is_huge=brics["area"]>8
brics[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %% [markdown]
# However, we can also write this in a one-liner: simply put the code that defines is_huge directly in the square brackets.

# %%
brics[brics["area"]>8]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %% [markdown]
# ### **Boolean Operators**
#
# Now we haven't used boolean operators yet. Remember that we used this logical_and function from the NumPy package to do an element wise boolean operation on NumPy arrays? Because Pandas is built on NumPy, you can also use that function here. Suppose you only want to keep the observations that have an area between 8 and 10 million square kilometers. After importing numpy as np, we can use the logical_and() function to create a Boolean Series. The only thing left to do is placing this code inside square brackets to subset brics appropriately.

# %%
import numpy as np
np.logical_and(brics["area"]>8, brics["area"]<10)
# Out:
# BR     True
# RU    False
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
brics[np.logical_and(brics["area"]>8, brics["area"]<10)]
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4
# CH   China   Beijing  9.597      1357.0
