# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40_days_of_Python/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ##  **Steps for making a basic bar plot**

# %%
#Step 1- importing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Step 2- set a theme
sns.set_theme(style='ticks', color_codes=True)

# %%
#Step 3- import data set
titanic = sns.load_dataset("titanic")
print(titanic)

#we are using in-built dataset you can also import your own data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Step 4- plot basic graph
p = sns.countplot(x= "sex", data=titanic)
plt.show()

# %%
#Step 5- plot basic graph with 2 variables (count plot)
p = sns.countplot(x= "sex", data=titanic, hue="class")
plt.show()

# %%
#Step 6- plot basic graph with 2 variables (count plot) with title
p = sns.countplot(x= "sex", data=titanic, hue="class")
p.set_title("Titanic")
plt.show()

# %% [markdown]
# ## **experimenting line plot**

# %%
#Basic line plot

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower = sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)

#adding title
plt.title("Flowers line plot")

#printing plot
plt.show()

# %%
#adding limits

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower = sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)

#adding title
plt.title("Flowers line plot")

#adding limit
plt.xlim(2)
plt.ylim(1)

#printing plot
plt.show()

# %%
#setting style

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#setting style
sns.set_style("dark")

#load dataset
flower = sns.load_dataset("iris")

#draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)

#adding title
plt.title("Flowers line plot")

#printing plot
plt.show()

# %%
#size of figure

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower = sns.load_dataset("iris")

#changing size of figure
plt.figure(figsize=(10,10))

#draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower)

#adding title
plt.title("Flowers line plot")

#printing plot
plt.show()

# %% [markdown]
# ## **experimenting bar plot**

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower = sns.load_dataset("iris")
flower

#bar plot

sns.barplot(x="species", y="petal_length", data=flower)
plt.show()

# %%
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#line plot
sns.barplot(x="species",y="petal_length",data=flower)
plt.show()

# %%
#line plot
sns.barplot(x="who", y="alone", hue="sex", data=titanic)
plt.show()

# %%
#line plot
sns.barplot(x="sex", y="alone", hue="who", data=titanic, order=["female","male"])
plt.show()

# %%
#grey
sns.barplot(x="sex", y="alone", hue="who", data=titanic, order=["female","male"], palette='dark:grey')
plt.show()

#red
sns.barplot(x="sex", y="alone", hue="who", data=titanic, order=["female","male"], palette='dark:red')
plt.show()

#green
sns.barplot(x="sex", y="alone", hue="who", data=titanic, order=["female","male"], palette='light:green')
plt.show()

# %%
#using colour pallete of seaborn
sns.barplot(x="sex", y="alone", hue="who", data=titanic,
            order=["female", "male"],
            color="red",
            palette="pastel")

plt.show()

# %%
#barplot
#median
from numpy import median

sns.barplot(x="class", y="fare", hue="sex", data=titanic, estimator=median)
plt.show()

# %%
#barplot
#mean
from numpy import mean

sns.barplot(x="class", y="fare", hue="sex", data=titanic, estimator=mean)
plt.show()

# %%
#barplot
#saturation
from numpy import mean

sns.barplot(x="class", y="fare", hue="sex", data=titanic, saturation=0.1)
plt.show()

# %%
#changes in barplot
#import libraries
import seaborn as sns
import numpy
import matplotlib.pyplot as plt

#load dataset
titanic = sns.load_dataset("titanic")
titanic

#bar plot
sns.barplot(x="class", y="fare", data=titanic,
            linewidth=2.5, facecolor=(1,1,1,0),
            err_kws={'color':'.2'}, edgecolor=".2")
plt.show()

# %% [markdown]
# ## **experimenting box plot**

# %%
#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
titanic = seaborn.load_dataset("titanic")

#basic boxplot
seaborn.boxplot(x="class",
                y="fare",
                data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
tip = seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#making box plot using tip dataset

#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
tip = seaborn.load_dataset("tips")

#basic boxplot
seaborn.boxplot(x="day", y="tip", data=tip, saturation=3)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#using describe func to get an overview of the data
#import library
import seaborn as sns
import numpy as np
import pandas as pf

#loading data
tip = sns.load_dataset("tips")
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
tip = seaborn.load_dataset("tips")

#basic boxplot
seaborn.boxplot(x=tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#vertical boxplot
#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
tip = seaborn.load_dataset("tips")

#boxplot
seaborn.boxplot(x='tip', y='day', data=tip)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#vertical boxplot

#import library
import seaborn

#setting style
seaborn.set(style="whitegrid")

#loading data
tip = seaborn.load_dataset("tips")

#boxplot
seaborn.boxplot(x='tip', y='day', hue='smoker', data=tip)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#Dodging or overlapping feature
seaborn.boxplot(x='tip', y='day', hue='smoker', data=tip,
                palette="Set2",dodge=False)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#using hex value as colour
seaborn.boxplot(x="day", y="tip", data=tip, color= '#99234f' )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#managing individual colors for each box
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Create a dictionary mapping each unique value in the 'day' column to a color
color_dict = {
    'Thur': '#99234f',
    'Fri': '#3498db',
    'Sat': '#2ecc71',
    'Sun': '#f1c40f'
}

# Create the boxplot with custom colors for each day
sns.boxplot(x="day", y="tip", data=tips, palette=color_dict)

plt.show()
# Out:
# <ipython-input-58-a0ea1487bc36>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="tip", data=tips, palette=color_dict)

# %%
#using built in color set
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.boxplot(x="day", y="tip",
            data=tips, palette="Set2")
plt.show()
# Out:
# <ipython-input-59-4da2cbe19696>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="tip",

# %%
#printing first 5 coloumns
#import libraries
import seaborn as sns
import pandas as pd
import numpy as np

#load dataset
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#basic boxplot
sns.boxplot(x='survived', y='age', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
#highlighting mean
sns.boxplot(x="survived",
            y="age", showmeans=True,
            data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
#doing changes in point used to show different estimators
sns.boxplot(x="survived",
            y="age", showmeans=True,
            meanprops={"marker":"*",
                       "markersize":"12",
                       "markeredgecolor":"red"},
            data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
#adding titles
fig, ax = plt.subplots()
sns.boxplot(x="survived", y="age", showmeans=True, data=titanic, ax=ax)

ax.set_xlabel("How many survived")
ax.set_ylabel("Age (years)")
ax.set_title("People survived by age")

plt.show()

# %%
#chnaging the size and weight of labels
fig, ax = plt.subplots()
sns.boxplot(x="survived", y="age", showmeans=True, data=titanic, ax=ax)

ax.set_xlabel("How many survived", size=15)
ax.set_ylabel("Age (years)", size=15)
ax.set_title("People survived by age",size = 20, weight="bold")

plt.show()

# %%
#h.w facet wrap and facet grid

# %% [markdown]
# ## **Line Plot with Multifacets**

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

titanic = sns.load_dataset('titanic')

# defining a color palette
palette = sns.color_palette('rocket_r')

# line plot
sns.relplot(
    data=titanic,
    x='age', y='fare',
    hue='class', size='survived', col='sex',
    kind='line', size_order=[0, 1], palette=palette,
    height=5, aspect=1.5, facet_kws=dict(sharex=False),
)

plt.show()
# Out:
# <ipython-input-2-9c9c7335fb4f>:12: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.relplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Nested boxplot
sns.boxplot(x='day', y='total_bill',
            hue='smoker', palette=['m','g'],
            data=tips, ax=ax)

# Remove spines and add despine
sns.despine(offset=10, trim=True)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Loading data
tips = sns.load_dataset('tips')

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Nested violin plot
sns.violinplot(data=tips, x='day', y='total_bill', hue='smoker',
               split=True, inner='quartile', linewidth=1,
               palette={'Yes': 'b', 'No': '.85'})

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='whitegrid')

#loading data
diamonds = sns.load_dataset('diamonds')

#scatter plot
f, ax = plt.subplots(figsize=(6.5,6.5))
sns.despine(f, left= True, bottom=True)
clarity_ranking=['I1','SI2','SI1', 'VS2','VS1','VVS2','VVS1','IF']
sns.scatterplot(x='carat',y='price',
                hue='clarity', size='depth',
                palette='ch:r=-.2,d=.3_r',
                hue_order=clarity_ranking,
                sizes=(1,8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='ticks')

f, ax = plt.subplots(figsize=(7,6))
ax.set_xscale('log')

#loading data
planets = sns.load_dataset('planets')

#plot the orbital period with horizontal boxes
sns.boxplot(x='distance',y='method', data=planets,
            whis=[0,100], width=6, palette='vlag')
#add in points to show each observation
sns.stripplot(x='distance',y='method', data=planets,
             size=4, color='.3', linewidth=0)

#tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel='')
sns.despine(trim=True, left=True)
# Out:
# <ipython-input-10-311a22a6ae77>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='distance',y='method', data=planets,

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# Load the planets dataset and initialize the figure
planets = sns.load_dataset("planets")
g = sns.JointGrid(data=planets, x="year", y="distance", marginal_ticks=True)

# Set a log scaling on the y axis
g.ax_joint.set(yscale="log")

# Create an inset legend for the histogram colorbar
cax = g.figure.add_axes([.15, .55, .02, .2])

# Add the joint and marginal histogram plots
g.plot_joint(
    sns.histplot, discrete=(True, False),
    cmap="light:#03012d", pmax=.8, cbar=True, cbar_ax=cax
)
g.plot_marginals(sns.histplot, element="step", color="#03012d")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(
    diamonds, x="clarity", y="carat",
    color="b", order=clarity_ranking, width_method="linear",
)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()

# Load the brain networks example dataset
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Select a subset of the networks
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Create a categorical palette to identify the networks
network_pal = sns.husl_palette(8, s=.45)
network_lut = dict(zip(map(str, used_networks), network_pal))

# Convert the palette to vectors that will be drawn on the side of the matrix
networks = df.columns.get_level_values("network")
network_colors = pd.Series(networks, index=df.columns).map(network_lut)

# Draw the full plot
g = sns.clustermap(df.corr(), center=0, cmap="vlag",
                   row_colors=network_colors, col_colors=network_colors,
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(.02, .32, .03, .2),
                   linewidths=.75, figsize=(12, 13))

g.ax_row_dendrogram.remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 6))

# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=corr_df, bw_adjust=.5, cut=1, linewidth=1, palette="Set3")

# Finalize the figure
ax.set(ylim=(-.7, 1.05))
sns.despine(left=True, bottom=True)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example planets dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme()

# Generate an example radial datast
r = np.linspace(0, 10, num=100)
df = pd.DataFrame({'r': r, 'slow': r, 'medium': 2 * r, 'fast': 4 * r})

# Convert the dataframe to long-form or "tidy" format
df = pd.melt(df, id_vars=['r'], var_name='speed', value_name='theta')

# Set up a grid of axes with a polar projection
g = sns.FacetGrid(df, col="speed", hue="speed",
                  subplot_kws=dict(projection='polar'), height=4.5,
                  sharex=False, sharey=False, despine=False)

# Draw a scatterplot onto each axes in the grid
g.map(sns.scatterplot, "theta", "r")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the dataset
crashes = sns.load_dataset("car_crashes")

# Make the PairGrid
g = sns.PairGrid(crashes.sort_values("total", ascending=False),
                 x_vars=crashes.columns[:-3], y_vars=["abbrev"],
                 height=10, aspect=.25)

# Draw a dot plot using the stripplot function
g.map(sns.stripplot, size=10, orient="h", jitter=False,
      palette="flare_r", linewidth=1, edgecolor="w")

# Use the same x axis limits on all columns and add better labels
g.set(xlim=(0, 25), xlabel="Crashes", ylabel="")

# Use semantically meaningful titles for the columns
titles = ["Total crashes", "Speeding crashes", "Alcohol crashes",
          "Not distracted crashes", "No previous crashes"]

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)

sns.despine(left=True, bottom=True)

# %% [markdown]
# All the available plots that seaborn library provides are here in the example gallery: https://seaborn.pydata.org/examples/index.html
