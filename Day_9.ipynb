# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40-days-of-Python/blob/main/Day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas in python**

# %%
import pandas as pd
import numpy as np

# %%
#object creation
s = pd.Series([1,3,5,7,9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
#putting NaN value
s = pd.Series([1,3,5,np.nan,7,9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
#making calender
dates = pd.date_range("20240101", periods=6)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.017079 -0.601909 -0.220147 -0.387157
# 2024-01-02  1.272723 -0.434233 -1.544299 -0.290057
# 2024-01-03 -0.978333 -0.222582 -0.285335  0.683045
# 2024-01-04 -0.923712  0.607740 -1.019400 -0.455062
# 2024-01-05 -2.271364 -0.419495 -0.494991 -0.562431
# 2024-01-06 -0.576070  0.524595 -0.588588 -1.227740

# %%
dates = pd.date_range("20240101", periods=6)
dates
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.033828  0.404175 -0.663090  0.899241
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242
# 2024-01-04  0.038750  0.028376  1.810668 -0.298173
# 2024-01-05 -0.006376 -0.708038  2.610310  2.089623
# 2024-01-06  0.206161  0.061626  0.141844 -0.959759

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B": pd.Timestamp("20241212"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E": pd.Categorical(["girl","woman","girl","woman"]),
        "F": "females",
    }
)

df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2024-12-12  1.0  3   girl  females
# 1  1.0 2024-12-12  1.0  3  woman  females
# 2  1.0 2024-12-12  1.0  3   girl  females
# 3  1.0 2024-12-12  1.0  3  woman  females

# %%
#checking data types
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
#to see the first few rows
df.head()
# Out:
#                    A         B         C         D
# 2024-01-01  0.033828  0.404175 -0.663090  0.899241
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242
# 2024-01-04  0.038750  0.028376  1.810668 -0.298173
# 2024-01-05 -0.006376 -0.708038  2.610310  2.089623

# %%
#to see the last few rows
df.tail()
# Out:
#                    A         B         C         D
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242
# 2024-01-04  0.038750  0.028376  1.810668 -0.298173
# 2024-01-05 -0.006376 -0.708038  2.610310  2.089623
# 2024-01-06  0.206161  0.061626  0.141844 -0.959759

# %%
#to see index
df.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[ 0.03382807,  0.40417527, -0.66309007,  0.89924077],
#        [-0.36323135, -0.01615981, -0.62541454,  2.30368027],
#        [ 0.11255103, -0.28643078,  1.30946226,  0.17024237],
#        [ 0.03875013,  0.02837647,  1.81066816, -0.2981728 ],
#        [-0.00637553, -0.70803788,  2.61030975,  2.08962262],
#        [ 0.20616134,  0.06162563,  0.14184361, -0.95975938]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.003614 -0.086075  0.763963  0.700809
# std    0.194790  0.376066  1.353221  1.309529
# min   -0.363231 -0.708038 -0.663090 -0.959759
# 25%    0.003675 -0.218863 -0.433600 -0.181069
# 50%    0.036289  0.006108  0.725653  0.534742
# 75%    0.094101  0.053313  1.685367  1.792027
# max    0.206161  0.404175  2.610310  2.303680

# %%
#transpose
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2024-12-12 00:00:00  2024-12-12 00:00:00  2024-12-12 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2024-12-12 00:00:00
# C                  1.0
# D                    3
# E                woman
# F              females

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2024-01-01  0.899241 -0.663090  0.404175  0.033828
# 2024-01-02  2.303680 -0.625415 -0.016160 -0.363231
# 2024-01-03  0.170242  1.309462 -0.286431  0.112551
# 2024-01-04 -0.298173  1.810668  0.028376  0.038750
# 2024-01-05  2.089623  2.610310 -0.708038 -0.006376
# 2024-01-06 -0.959759  0.141844  0.061626  0.206161

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D
# 2024-01-01  0.033828  0.404175 -0.663090  0.899241
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242
# 2024-01-04  0.038750  0.028376  1.810668 -0.298173
# 2024-01-05 -0.006376 -0.708038  2.610310  2.089623
# 2024-01-06  0.206161  0.061626  0.141844 -0.959759

# %%
df.sort_values(by='B', ascending=True)
# Out:
#                    A         B         C         D
# 2024-01-05 -0.006376 -0.708038  2.610310  2.089623
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-04  0.038750  0.028376  1.810668 -0.298173
# 2024-01-06  0.206161  0.061626  0.141844 -0.959759
# 2024-01-01  0.033828  0.404175 -0.663090  0.899241

# %%
df['A']
# Out:
# 2024-01-01    0.033828
# 2024-01-02   -0.363231
# 2024-01-03    0.112551
# 2024-01-04    0.038750
# 2024-01-05   -0.006376
# 2024-01-06    0.206161
# Freq: D, Name: A, dtype: float64

# %%
#row wise selection
df[0:3]
# Out:
#                    A         B         C         D
# 2024-01-01  0.033828  0.404175 -0.663090  0.899241
# 2024-01-02 -0.363231 -0.016160 -0.625415  2.303680
# 2024-01-03  0.112551 -0.286431  1.309462  0.170242

# %%
df.loc[dates[0]]
# Out:
# A    0.033828
# B    0.404175
# C   -0.663090
# D    0.899241
# Name: 2024-01-01 00:00:00, dtype: float64
