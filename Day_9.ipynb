# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40_days_of_Python/blob/main/Day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas in python**

# %%
import pandas as pd
import numpy as np

# %%
#object creation
s = pd.Series([1,3,5,7,9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
#putting NaN value
s = pd.Series([1,3,5,np.nan,7,9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
#making calender
dates = pd.date_range("20240101", periods=6)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.122988 -0.073193 -1.476146  0.886983
# 2024-01-02 -2.166732  0.068496 -0.025915 -0.486423
# 2024-01-03  1.164679  1.295895 -0.227505 -1.039292
# 2024-01-04  1.478948  1.249281 -2.522862 -0.867962
# 2024-01-05  0.911782 -0.218701 -0.391865 -1.510482
# 2024-01-06  0.099569  0.241148  0.054621  0.354671

# %%
dates = pd.date_range("20240101", periods=6)
dates
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.502329 -1.173305 -0.599285 -0.234365
# 2024-01-02 -0.230024 -0.093568  0.722958 -1.207533
# 2024-01-03  0.902954  1.785045  1.020225 -1.050446
# 2024-01-04  0.595592  0.100745  0.524645  0.687358
# 2024-01-05  0.719856 -2.027486 -2.040645  1.355086
# 2024-01-06  1.127325 -0.438503  0.001978 -1.012836

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B": pd.Timestamp("20241212"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E": pd.Categorical(["girl","woman","girl","woman"]),
        "F": "females",
    }
)

df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2024-12-12  1.0  3   girl  females
# 1  1.0 2024-12-12  1.0  3  woman  females
# 2  1.0 2024-12-12  1.0  3   girl  females
# 3  1.0 2024-12-12  1.0  3  woman  females

# %%
#checking data types
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
#to see the first few rows
df.head()
# Out:
#                    A         B         C         D
# 2024-01-01  0.502329 -1.173305 -0.599285 -0.234365
# 2024-01-02 -0.230024 -0.093568  0.722958 -1.207533
# 2024-01-03  0.902954  1.785045  1.020225 -1.050446
# 2024-01-04  0.595592  0.100745  0.524645  0.687358
# 2024-01-05  0.719856 -2.027486 -2.040645  1.355086

# %%
#to see the last few rows
df.tail()
# Out:
#                    A         B         C         D
# 2024-01-02 -0.230024 -0.093568  0.722958 -1.207533
# 2024-01-03  0.902954  1.785045  1.020225 -1.050446
# 2024-01-04  0.595592  0.100745  0.524645  0.687358
# 2024-01-05  0.719856 -2.027486 -2.040645  1.355086
# 2024-01-06  1.127325 -0.438503  0.001978 -1.012836

# %%
#to see index
df.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[ 5.02328942e-01, -1.17330476e+00, -5.99285337e-01,
#         -2.34365461e-01],
#        [-2.30023709e-01, -9.35676369e-02,  7.22957773e-01,
#         -1.20753323e+00],
#        [ 9.02954459e-01,  1.78504538e+00,  1.02022459e+00,
#         -1.05044567e+00],
#        [ 5.95591582e-01,  1.00744967e-01,  5.24644534e-01,
#          6.87358311e-01],
#        [ 7.19855917e-01, -2.02748598e+00, -2.04064550e+00,
#          1.35508623e+00],
#        [ 1.12732496e+00, -4.38502785e-01,  1.97841080e-03,
#         -1.01283555e+00]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.603005 -0.307845 -0.061688 -0.243789
# std    0.465331  1.289675  1.125995  1.057777
# min   -0.230024 -2.027486 -2.040645 -1.207533
# 25%    0.525645 -0.989604 -0.448969 -1.041043
# 50%    0.657724 -0.266035  0.263311 -0.623601
# 75%    0.857180  0.052167  0.673379  0.456927
# max    1.127325  1.785045  1.020225  1.355086

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2024-12-12 00:00:00  2024-12-12 00:00:00  2024-12-12 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2024-12-12 00:00:00
# C                  1.0
# D                    3
# E                woman
# F              females
