# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40-days-of-Python/blob/main/Day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas in python**

# %%
import pandas as pd
import numpy as np

# %%
#object creation
s = pd.Series([1,3,5,7,9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
#putting NaN value
s = pd.Series([1,3,5,np.nan,7,9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
#making calender
dates = pd.date_range("20240101", periods=6)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  1.231378  0.400001 -0.231653 -0.349622
# 2024-01-02  0.264726  0.446322  0.659330 -0.819385
# 2024-01-03  0.859967  0.012857 -0.897388  0.188895
# 2024-01-04 -0.913358  1.718356 -1.017759 -0.914197
# 2024-01-05  1.516604 -1.456241  0.631321  0.910168
# 2024-01-06 -0.159186 -0.303841 -0.263908  0.544821

# %%
dates = pd.date_range("20240101", periods=6)
dates
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B": pd.Timestamp("20241212"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E": pd.Categorical(["girl","woman","girl","woman"]),
        "F": "females",
    }
)

df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2024-12-12  1.0  3   girl  females
# 1  1.0 2024-12-12  1.0  3  woman  females
# 2  1.0 2024-12-12  1.0  3   girl  females
# 3  1.0 2024-12-12  1.0  3  woman  females

# %%
#checking data types
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
#to see the first few rows
df.head()
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132

# %%
#to see the last few rows
df.tail()
# Out:
#                    A         B         C         D
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869

# %%
#to see index
df.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[ 0.68639185, -0.68234517,  0.47745453,  0.02206939],
#        [-0.56607109,  0.47623901,  0.22425936,  1.93646661],
#        [-0.41653548,  1.30599351, -0.87768573, -0.95672323],
#        [ 2.05360859,  0.39764612,  0.17849182,  0.48663681],
#        [-1.12649723, -1.60800126,  0.58646777, -0.73613165],
#        [-0.81189622,  0.90704503, -0.1614284 ,  1.09886901]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.030167  0.132763  0.071260  0.308531
# std    1.192065  1.082477  0.532913  1.102795
# min   -1.126497 -1.608001 -0.877686 -0.956723
# 25%   -0.750440 -0.412347 -0.076448 -0.546581
# 50%   -0.491303  0.436943  0.201376  0.254353
# 75%    0.410660  0.799344  0.414156  0.945811
# max    2.053609  1.305994  0.586468  1.936467

# %%
#transpose
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2024-12-12 00:00:00  2024-12-12 00:00:00  2024-12-12 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 girl                woman                 girl
# F              females              females              females
#
#                      3
# A                  1.0
# B  2024-12-12 00:00:00
# C                  1.0
# D                    3
# E                woman
# F              females

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2024-01-01  0.022069  0.477455 -0.682345  0.686392
# 2024-01-02  1.936467  0.224259  0.476239 -0.566071
# 2024-01-03 -0.956723 -0.877686  1.305994 -0.416535
# 2024-01-04  0.486637  0.178492  0.397646  2.053609
# 2024-01-05 -0.736132  0.586468 -1.608001 -1.126497
# 2024-01-06  1.098869 -0.161428  0.907045 -0.811896

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869

# %%
df.sort_values(by='B', ascending=True)
# Out:
#                    A         B         C         D
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723

# %%
df['A']
# Out:
# 2024-01-01    0.686392
# 2024-01-02   -0.566071
# 2024-01-03   -0.416535
# 2024-01-04    2.053609
# 2024-01-05   -1.126497
# 2024-01-06   -0.811896
# Freq: D, Name: A, dtype: float64

# %%
#row wise selection
df[0:3]
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723

# %%
df.loc[dates[0]]
# Out:
# A    0.686392
# B   -0.682345
# C    0.477455
# D    0.022069
# Name: 2024-01-01 00:00:00, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2024-01-01  0.686392 -0.682345
# 2024-01-02 -0.566071  0.476239
# 2024-01-03 -0.416535  1.305994
# 2024-01-04  2.053609  0.397646
# 2024-01-05 -1.126497 -1.608001
# 2024-01-06 -0.811896  0.907045

# %%
df.loc[["20240102","20240104"], ["A","B"]]
# Out:
#                    A         B
# 2024-01-02 -0.566071  0.476239
# 2024-01-04  2.053609  0.397646

# %%
df.loc[["20240102"], ["A","B","C"]]
# Out:
#                    A         B         C
# 2024-01-02 -0.566071  0.476239  0.224259

# %%
df.at[dates[0],"A"]
# Out:
# 0.6863918458037844

# %%
df.iloc[3]
# Out:
# A    2.053609
# B    0.397646
# C    0.178492
# D    0.486637
# Name: 2024-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:10]
# Out:
#                    A         B         C         D
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869

# %%
df.iloc[0:5,10:15]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2024-01-01 00:00:00, 2024-01-02 00:00:00, 2024-01-03 00:00:00, 2024-01-04 00:00:00, 2024-01-05 00:00:00]

# %%
df.iloc[0:5,:]
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132

# %%
df.iloc[:,0:2]
# Out:
#                    A         B
# 2024-01-01  0.686392 -0.682345
# 2024-01-02 -0.566071  0.476239
# 2024-01-03 -0.416535  1.305994
# 2024-01-04  2.053609  0.397646
# 2024-01-05 -1.126497 -1.608001
# 2024-01-06 -0.811896  0.907045

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-04  2.053609  0.397646  0.178492  0.486637

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392       NaN  0.477455  0.022069
# 2024-01-02       NaN  0.476239  0.224259  1.936467
# 2024-01-03       NaN  1.305994       NaN       NaN
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05       NaN       NaN  0.586468       NaN
# 2024-01-06       NaN  0.907045       NaN  1.098869

# %%
df2 = df.copy()

# %%
df2["E"]=["one","one","two","three","four","three"]

# %%
df2["mean"]=[1.2,2.3,3.3,4,5,6]
df2
# Out:
#                    A         B         C         D      E  mean
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069    one   1.2
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467    one   2.3
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723    two   3.3
# 2024-01-04  2.053609  0.397646  0.178492  0.486637  three   4.0
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132   four   5.0
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869  three   6.0

# %%
df2 = df2.iloc[:,0:4]
df2
# Out:
#                    A         B         C         D
# 2024-01-01  0.686392 -0.682345  0.477455  0.022069
# 2024-01-02 -0.566071  0.476239  0.224259  1.936467
# 2024-01-03 -0.416535  1.305994 -0.877686 -0.956723
# 2024-01-04  2.053609  0.397646  0.178492  0.486637
# 2024-01-05 -1.126497 -1.608001  0.586468 -0.736132
# 2024-01-06 -0.811896  0.907045 -0.161428  1.098869
