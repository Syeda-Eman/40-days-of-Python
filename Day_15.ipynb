# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/40-days-of-Python/blob/main/Day_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %%
import pandas as pd

# %%
brics = pd.read_csv("/content/brics.csv", index_col=0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# # **Dataframe from dictionary**

# %%
dict = {
    "country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "area": ["8.516", "17.10", "3.286", "9.597", "1.221"],
    "population": ["200.4", "143.5", "1252", "1357", "52.98"]
}

# %%
import pandas as pd
bric = pd.DataFrame(dict)

# %%
bric
# Out:
#         country    capital   area population
# 0        Brazil   Brasilia  8.516      200.4
# 1        Russia     Moscow  17.10      143.5
# 2         India  New Delhi  3.286       1252
# 3         China    Beijing  9.597       1357
# 4  South Africa   Pretoria  1.221      52.98

# %%
#Adding index
bric.index=["BR","RU","IN","CH","SA"]
bric
# Out:
#          country    capital   area population
# BR        Brazil   Brasilia  8.516      200.4
# RU        Russia     Moscow  17.10      143.5
# IN         India  New Delhi  3.286       1252
# CH         China    Beijing  9.597       1357
# SA  South Africa   Pretoria  1.221      52.98
